# %%
import numpy as np
from gensim.models import KeyedVectors
import operator
from sklearn.manifold import TSNE
import random
import plotly.graph_objects as go

# %%
w2c_100_path = './word2vec100/word2vec_100_3_polish.bin'
w2c_300_path = './word2vec300/word2vec_300_3_polish.bin'

# %%
w2v_100 = KeyedVectors.load(w2c_100_path)
w2v_300 = KeyedVectors.load(w2c_300_path)

# %%
def find_most_similar(word, model, model_name, top_n):
    most_similar = model.wv.most_similar(word, topn=top_n)
    print_most_similar(word, model_name, top_n, most_similar)

def find_most_similar_bigrams(bigram, model, model_name, top_n):
    w1, w2 = bigram.split(' ')
    w1_vec = model.wv.get_vector(w1)
    w2_vec = model.wv.get_vector(w2)
    vec = (w1_vec + w2_vec)/2
    most_similar = model.wv.similar_by_vector(vec, topn=top_n)
    print_most_similar(bigram, model_name, top_n, most_similar)
    
def find_most_similar_equations(equation, model, model_name, top_n):    
    vec = eq2vec(equation, model)
    most_similar = model.wv.similar_by_vector(vec, topn=top_n) 
    print_most_similar(equation, model_name, top_n, most_similar)

def eq2vec(equation, model):
    eq_components = equation.split(' ')
    operands = [eq_components[i] for i in range(1, len(eq_components), 2)]
    factors = [eq_components[i] for i in range(0, len(eq_components), 2)]
    vecs = [model.wv.get_vector(word) for word in factors]
    vec = ops[operands[1]](ops[operands[0]](vecs[0],  vecs[1]), vecs[2])
    return vec

def print_most_similar(word, model_name, top_n, similar_words):
    print(f'\n{top_n} most similar words for {word} using {model_name}')
    for i in range(top_n):
        print(f'\t{i+1}. {similar_words[i]}')
        
        
def make_TSNE_plot(vecs_embedded, highlighted, random_words, title):
    h_len = len(highlighted)
    fig = go.Figure()
    fig.add_trace(
        go.Scatter(
            x=vecs_embedded[h_len:,0],
            y=vecs_embedded[h_len:,1],
            mode='markers',
            name='random',
            text=random_words
        )
    )
    fig.add_trace(
        go.Scatter(
            x=vecs_embedded[:h_len,0],
            y=vecs_embedded[:h_len,1],
            mode='markers',
            name='highlighted',
            text=highlighted
        )
    )
    fig.update_layout(title=title)
    fig.show()

# %% [markdown]
# ## Using the downloaded models find the most similar words for the following expressions:
# * kpk
# * szkoda
# * wypadek
# * kolizja
# * nieszczęście
# * rozwód

# %%
words = ['kpk', 'szkoda', 'wypadek', 'kolizja', 'nieszczęście', 'rozwód']
top_n = 5
for word in words:
    find_most_similar(word, w2v_100, 'w2v_100', top_n)
    find_most_similar(word, w2v_300, 'w2v_300', top_n)
    print('----------------------------------------------------------------')
# Out:
# <ipython-input-66-3fa6158bfd18>:2: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   most_similar = model.wv.most_similar(word, topn=top_n)
# 5 most similar words for kpk using w2v_100
# 	1. ('kilopond', 0.6665806770324707)
# 	2. ('kpzs', 0.6363496780395508)
# 	3. ('kpu', 0.6300562024116516)
# 	4. ('sownarkomu', 0.6254925727844238)
# 	5. ('wcik', 0.6224358677864075)
#
# 5 most similar words for kpk using w2v_300
# 	1. ('ksh', 0.5774794220924377)
# 	2. ('cywilnego', 0.5498510599136353)
# 	3. ('postępowania', 0.5285828113555908)
# 	4. ('kilopond', 0.5151568055152893)
# 	5. ('kkkw', 0.48344212770462036)
# ----------------------------------------------------------------
#
# 5 most similar words for szkoda using w2v_100
# 	1. ('krzywda', 0.6817898750305176)
# 	2. ('pożytek', 0.6121943593025208)
# 	3. ('strata', 0.5968126654624939)
# 	4. ('ryzyko', 0.5745570659637451)
# 	5. ('uszczerbek', 0.5639551877975464)
#
# 5 most similar words for szkoda using w2v_300
# 	1. ('uszczerbek', 0.6027276515960693)
# 	2. ('krzywda', 0.5920778512954712)
# 	3. ('strata', 0.550269365310669)
# 	4. ('despekt', 0.5382484197616577)
# 	5. ('pożytek', 0.531347393989563)
# ----------------------------------------------------------------
#
# 5 most similar words for wypadek using w2v_100
# 	1. ('przypadek', 0.7544811964035034)
# 	2. ('okoliczności', 0.7268072366714478)
# 	3. ('padku', 0.6788284182548523)
# 	4. ('incydent', 0.6418948173522949)
# 	5. ('zdarzenie', 0.6114422082901001)
#
# 5 most similar words for wypadek using w2v_300
# 	1. ('przypadek', 0.7066895961761475)
# 	2. ('okoliczności', 0.6121077537536621)
# 	3. ('padku', 0.6056742072105408)
# 	4. ('padki', 0.5596078634262085)
# 	5. ('incydent', 0.5496981143951416)
# ----------------------------------------------------------------
#
# 5 most similar words for kolizja using w2v_100
# 	1. ('zderzenie', 0.8431548476219177)
# 	2. ('awaria', 0.7090569734573364)
# 	3. ('kraksa', 0.6777161359786987)
# 	4. ('turbulencja', 0.6613468527793884)
# 	5. ('poślizg', 0.6391660571098328)
#
# 5 most similar words for kolizja using w2v_300
# 	1. ('zderzenie', 0.7603178024291992)
# 	2. ('awaria', 0.611009955406189)
# 	3. ('kraksa', 0.5939033031463623)
# 	4. ('turbulencja', 0.5664489269256592)
# 	5. ('poślizg', 0.5569967031478882)
# ----------------------------------------------------------------
#
# 5 most similar words for nieszczęście using w2v_100
# 	1. ('niebezpieczeństwo', 0.7519958019256592)
# 	2. ('cierpienia', 0.7408335208892822)
# 	3. ('strapienie', 0.7345459461212158)
# 	4. ('cierpienie', 0.7262567281723022)
# 	5. ('utrapienie', 0.7251379489898682)
#
# 5 most similar words for nieszczęście using w2v_300
# 	1. ('utrapienie', 0.6610732674598694)
# 	2. ('cierpienia', 0.6526124477386475)
# 	3. ('niedola', 0.6478177309036255)
# 	4. ('strapienie', 0.6300181150436401)
# 	5. ('cierpienie', 0.6248573064804077)
# ----------------------------------------------------------------
#
# 5 most similar words for rozwód using w2v_100
# 	1. ('małżeństwo', 0.7646843194961548)
# 	2. ('separacja', 0.7547168135643005)
# 	3. ('adopcja', 0.7333694696426392)
# 	4. ('ślub', 0.7324203848838806)
# 	5. ('unieważnienie', 0.7096400856971741)
#
# 5 most similar words for rozwód using w2v_300
# 	1. ('separacja', 0.7053208351135254)
# 	2. ('małżeństwo', 0.6689504384994507)
# 	3. ('ślub', 0.6553219556808472)
# 	4. ('rozwodowy', 0.614338219165802)
# 	5. ('unieważnienie', 0.6127183437347412)
# ----------------------------------------------------------------

# %% [markdown]
# Możemy zobaczyć, że w większości przypadków model stu i trzystu wymiarowy dały bardzo podobne wyniki. W przypadku KPK jednak mniejszy model nie znalazł żadnych sensownych podobnych słów, natomiast większy znalazł chociażby 'cywilnego' i 'postępowania'.

# %% [markdown]
# ## Find the most similar words for the following expressions (average the representations for each word):
# * sąd najwyższy
# * trybunał konstytucyjny
# * szkoda majątkowy
# * kodeks cywilny
# * sąd rejonowy

# %%
bigrams = ['sąd najwyższy', 'trybunał konstytucyjny', 'szkoda majątkowy', 'kodeks cywilny', 'sąd rejonowy']
top_n = 7

# %%
for bigram in bigrams:
    find_most_similar_bigrams(bigram, w2v_100, 'w2v_100', top_n)
    find_most_similar_bigrams(bigram, w2v_300, 'w2v_300', top_n)
    print('----------------------------------------------------------------')
# Out:
# <ipython-input-66-3fa6158bfd18>:7: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   w1_vec = model.wv.get_vector(w1)
# <ipython-input-66-3fa6158bfd18>:8: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   w2_vec = model.wv.get_vector(w2)
# <ipython-input-66-3fa6158bfd18>:10: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   most_similar = model.wv.similar_by_vector(vec, topn=top_n)
# 5 most similar words for sąd najwyższy using w2v_100
# 	1. ('sąd', 0.8644266128540039)
# 	2. ('trybunał', 0.7672435641288757)
# 	3. ('najwyższy', 0.7527138590812683)
# 	4. ('trybunat', 0.6843459010124207)
# 	5. ('sędzia', 0.6718415021896362)
#
# 5 most similar words for sąd najwyższy using w2v_300
# 	1. ('sąd', 0.8261206150054932)
# 	2. ('trybunał', 0.711520791053772)
# 	3. ('najwyższy', 0.7068409323692322)
# 	4. ('sędzia', 0.6023203730583191)
# 	5. ('sądowy', 0.5670486688613892)
# ----------------------------------------------------------------
#
# 5 most similar words for trybunał konstytucyjny using w2v_100
# 	1. ('trybunał', 0.9073251485824585)
# 	2. ('konstytucyjny', 0.7998723387718201)
# 	3. ('sąd', 0.7972990274429321)
# 	4. ('bunał', 0.7729247808456421)
# 	5. ('senat', 0.7585273385047913)
#
# 5 most similar words for trybunał konstytucyjny using w2v_300
# 	1. ('trybunał', 0.8845913410186768)
# 	2. ('konstytucyjny', 0.7739969491958618)
# 	3. ('sąd', 0.7300779819488525)
# 	4. ('trybunat', 0.6758428812026978)
# 	5. ('senat', 0.6632090210914612)
# ----------------------------------------------------------------
#
# 5 most similar words for szkoda majątkowy using w2v_100
# 	1. ('szkoda', 0.8172438144683838)
# 	2. ('majątkowy', 0.7424530386924744)
# 	3. ('krzywda', 0.6498408317565918)
# 	4. ('świadczenie', 0.6419471502304077)
# 	5. ('odszkodowanie', 0.6392182111740112)
#
# 5 most similar words for szkoda majątkowy using w2v_300
# 	1. ('szkoda', 0.7971925735473633)
# 	2. ('majątkowy', 0.7278684973716736)
# 	3. ('uszczerbek', 0.5841633081436157)
# 	4. ('korzyść', 0.5474051237106323)
# 	5. ('krzywda', 0.5431190729141235)
# ----------------------------------------------------------------
#
# 5 most similar words for kodeks cywilny using w2v_100
# 	1. ('kodeks', 0.8756389617919922)
# 	2. ('cywilny', 0.8532464504241943)
# 	3. ('pasztunwali', 0.6438998579978943)
# 	4. ('deksu', 0.6374959945678711)
# 	5. ('teodozjańskim', 0.6283917427062988)
#
# 5 most similar words for kodeks cywilny using w2v_300
# 	1. ('kodeks', 0.8212110996246338)
# 	2. ('cywilny', 0.7886406779289246)
# 	3. ('amiatyński', 0.5660314559936523)
# 	4. ('cywilnego', 0.5531740188598633)
# 	5. ('deksu', 0.5472918748855591)
# ----------------------------------------------------------------
#
# 5 most similar words for sąd rejonowy using w2v_100
# 	1. ('sąd', 0.8773891925811768)
# 	2. ('prokuratura', 0.8396657705307007)
# 	3. ('rejonowy', 0.7694871425628662)
# 	4. ('trybunał', 0.755321204662323)
# 	5. ('sądowy', 0.7153753042221069)
#
# 5 most similar words for sąd rejonowy using w2v_300
# 	1. ('sąd', 0.8507211208343506)
# 	2. ('rejonowy', 0.7344856262207031)
# 	3. ('prokuratura', 0.711697518825531)
# 	4. ('trybunał', 0.6748420596122742)
# 	5. ('sądowy', 0.6426382064819336)
# ----------------------------------------------------------------

# %% [markdown]
# W tym przypadku ponownie oba modele dały zadowalające rezultaty, często różniąc się jedynie kolejnością w liście najbardziej podobnych.

# %% [markdown]
# ## Find the result of the following equations (5 top results, both models):
# * sąd + konstytucja - kpk
# * pasażer + kobieta - mężczyzna
# * pilot + kobieta - mężczyzna
# * lekarz + kobieta - mężczyzna
# * nauczycielka + mężczyzna - kobieta
# * przedszkolanka + mężczyzna - 'kobieta
# * samochód + rzeka - droga

# %%
equations = ['sąd + konstytucja - kpk', 'pasażer + kobieta - mężczyzna', 'pilot + kobieta - mężczyzna',
             'lekarz + kobieta - mężczyzna' ,'nauczycielka + mężczyzna - kobieta', 
             'przedszkolanka + mężczyzna - kobieta', 'samochód + rzeka - droga']
ops = { "+": operator.add, "-": operator.sub }
top_n = 5

# %%
for equation in equations:
    find_most_similar_equations(equation, w2v_100, 'w2v_100', top_n)
    find_most_similar_equations(equation, w2v_300, 'w2v_300', top_n)
    print('----------------------------------------------------------------')
# Out:
# <ipython-input-107-5a3eedc16832>:22: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   vecs = [model.wv.get_vector(word) for word in factors]
# <ipython-input-107-5a3eedc16832>:15: DeprecationWarning: Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#   most_similar = model.wv.similar_by_vector(vec, topn=top_n)
# 5 most similar words for sąd + konstytucja - kpk using w2v_100
# 	1. ('sąd', 0.8484209775924683)
# 	2. ('konstytucja', 0.8322000503540039)
# 	3. ('trybunał', 0.7756364345550537)
# 	4. ('ustawa', 0.768037736415863)
# 	5. ('dekret', 0.7208969593048096)
#
# 5 most similar words for sąd + konstytucja - kpk using w2v_300
# 	1. ('sąd', 0.8255324363708496)
# 	2. ('konstytucja', 0.798995852470398)
# 	3. ('trybunał', 0.7041962146759033)
# 	4. ('ustawa', 0.6793721914291382)
# 	5. ('dekret', 0.6163084506988525)
# ----------------------------------------------------------------
#
# 5 most similar words for pasażer + kobieta - mężczyzna using w2v_100
# 	1. ('pasażer', 0.8446224927902222)
# 	2. ('pasażerka', 0.722925066947937)
# 	3. ('stewardessa', 0.629162073135376)
# 	4. ('stewardesa', 0.6267591714859009)
# 	5. ('taksówka', 0.6172000765800476)
#
# 5 most similar words for pasażer + kobieta - mężczyzna using w2v_300
# 	1. ('pasażer', 0.794208288192749)
# 	2. ('pasażerka', 0.6724309325218201)
# 	3. ('stewardesa', 0.5788161158561707)
# 	4. ('stewardessa', 0.563020646572113)
# 	5. ('podróżny', 0.4986627697944641)
# ----------------------------------------------------------------
#
# 5 most similar words for pilot + kobieta - mężczyzna using w2v_100
# 	1. ('pilot', 0.7940387725830078)
# 	2. ('nawigator', 0.6515690088272095)
# 	3. ('pilotka', 0.6387545466423035)
# 	4. ('oblatywacz', 0.6349523663520813)
# 	5. ('stewardesa', 0.6295650005340576)
#
# 5 most similar words for pilot + kobieta - mężczyzna using w2v_300
# 	1. ('pilot', 0.7508397102355957)
# 	2. ('pilotka', 0.6002969741821289)
# 	3. ('stewardesa', 0.5863654613494873)
# 	4. ('lotnik', 0.5733345150947571)
# 	5. ('nawigator', 0.5510674715042114)
# ----------------------------------------------------------------
#
# 5 most similar words for lekarz + kobieta - mężczyzna using w2v_100
# 	1. ('lekarz', 0.8562706708908081)
# 	2. ('lekarka', 0.7652443051338196)
# 	3. ('ginekolog', 0.7425668239593506)
# 	4. ('pediatra', 0.7326033115386963)
# 	5. ('położna', 0.7233613729476929)
#
# 5 most similar words for lekarz + kobieta - mężczyzna using w2v_300
# 	1. ('lekarz', 0.8074660301208496)
# 	2. ('lekarka', 0.7328401803970337)
# 	3. ('pielęgniarka', 0.6605410575866699)
# 	4. ('ginekolog', 0.6406487226486206)
# 	5. ('psychiatra', 0.6178667545318604)
# ----------------------------------------------------------------
#
# 5 most similar words for nauczycielka + mężczyzna - kobieta using w2v_100
# 	1. ('nauczycielka', 0.7924741506576538)
# 	2. ('uczennica', 0.6995393633842468)
# 	3. ('nauczyciel', 0.6980242133140564)
# 	4. ('studentka', 0.6898146271705627)
# 	5. ('wychowawczyni', 0.6681313514709473)
#
# 5 most similar words for nauczycielka + mężczyzna - kobieta using w2v_300
# 	1. ('nauczycielka', 0.7335864305496216)
# 	2. ('nauczyciel', 0.6324899792671204)
# 	3. ('wychowawczyni', 0.5766865015029907)
# 	4. ('uczennica', 0.5704265236854553)
# 	5. ('kolega', 0.5362026691436768)
# ----------------------------------------------------------------
#
# 5 most similar words for przedszkolanka + mężczyzna - kobieta using w2v_100
# 	1. ('dryblas', 0.6126624345779419)
# 	2. ('chudzielec', 0.5937358140945435)
# 	3. ('pielęgniarz', 0.5867979526519775)
# 	4. ('brodacz', 0.5754127502441406)
# 	5. ('motorzysta', 0.5742693543434143)
#
# 5 most similar words for przedszkolanka + mężczyzna - kobieta using w2v_300
# 	1. ('dryblas', 0.4693624973297119)
# 	2. ('osiłek', 0.4516163468360901)
# 	3. ('okularnik', 0.4439833164215088)
# 	4. ('policjant', 0.4331684410572052)
# 	5. ('ochroniarz', 0.4320264458656311)
# ----------------------------------------------------------------
#
# 5 most similar words for samochód + rzeka - droga using w2v_100
# 	1. ('samochód', 0.6177356243133545)
# 	2. ('jeep', 0.586937427520752)
# 	3. ('jezioro', 0.575423538684845)
# 	4. ('rzeka', 0.5726844072341919)
# 	5. ('ponton', 0.5713851451873779)
#
# 5 most similar words for samochód + rzeka - droga using w2v_300
# 	1. ('samochód', 0.5695928335189819)
# 	2. ('rzeka', 0.5316683053970337)
# 	3. ('dżip', 0.516063928604126)
# 	4. ('jeep', 0.5131956338882446)
# 	5. ('auto', 0.5062026381492615)
# ----------------------------------------------------------------

# %% [markdown]
# W tym bardziej skomplikowanym zadaniu możemy dostrzec większą przewagę modelu o wyższej wymiarowości. Dla przykładu 'pasażer + kobieta - mężczyzna' mniejszy model zamiast 'podróżny' znalazł słowo taksówka gdyż jest ono również rodzaju żeńskiego. Ostatni przypadek ('samochód + rzeka - droga') również na korzyść większego modelu, który znalazł wszystkie słowa powiązane z samochodem, gdy mniejszy znalazł np. 'ponton'

# %% [markdown]
# ## Using the t-SNE algorithm compute the projection of the random 1000 words with the following words highlighted (both models):
# * szkoda
# * strata
# * uszczerbek
# * krzywda
# * niesprawiedliwość
# * nieszczęście
# * kobieta
# * mężczyzna
# * pasażer
# * pasażerka
# * student
# * studentka
# * lekarz
# * lekarka

# %%
random_vecs_100 = []
random_words_100 = []
random_vecs_300 = []
random_words_300 = []
for i in range(1000):
    w = random.choice(w2v_100.wv.index2entity)
    random_words_100.append(w)
    random_words_300.append(w)
    random_vecs_100.append(w2v_100.wv[w])
    random_vecs_300.append(w2v_300.wv[w])

random_vecs_100 = np.array(random_vecs_100)
random_vecs_300 = np.array(random_vecs_300)
highlighted_words = ['szkoda', 'strata', 'uszczerbek', 'krzywda', 'niesprawiedliwość', 'nieszczęście', 'kobieta', 
         'mężczyzna', 'pasażer', 'pasażerka', 'student', 'studentka', 'lekarz', 'lekarka']
# Out:
# <ipython-input-209-cac9c5c25f56>:6: DeprecationWarning:
#
# Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).
#
# <ipython-input-209-cac9c5c25f56>:9: DeprecationWarning:
#
# Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
highlighted_vecs_100 = [w2v_100.wv.get_vector(word) for word in highlighted_words]
highlighted_vecs_300 = [w2v_300.wv.get_vector(word) for word in highlighted_words]
# Out:
# <ipython-input-210-957b257f66f2>:1: DeprecationWarning:
#
# Call to deprecated `wv` (Attribute will be removed in 4.0.0, use self instead).

# %%
vecs_100 = np.concatenate((highlighted_vecs_100, random_vecs_100))
vecs_300 = np.concatenate((highlighted_vecs_300, random_vecs_300))

# %%
vecs_100_embedded = TSNE(n_components=2).fit_transform(vecs_100)
vecs_300_embedded = TSNE(n_components=2).fit_transform(vecs_300)

# %%
make_TSNE_plot(vecs_100_embedded, highlighted_words, random_words_100, 'TSNE plot for w2v_100')
# Out:
# <div>                            <div id="9a2d21b0-169e-4840-a717-f618d332392e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("9a2d21b0-169e-4840-a717-f618d332392e")) {                    Plotly.newPlot(                        "9a2d21b0-169e-4840-a717-f618d332392e",                        [{"mode": "markers", "name": "random", "text": ["verlucca", "bhalder", "myelmizacji", "mangowy", "ewellowie", "rohling", "romeyko", "socialphobia", "l'anello", "chapeaumange", "vaclavem", "nfe", "leptonektes", "wysznewe", "rozwioz\u0142o\u015b\u0107", "treason", "knowlesi", "lupulinus", "tej\u013ee", "pok\u0142onim", "nowobabilo\u0144czyk\u00f3w", "tilenau", "muzza", "mianta", "perittia", "si\u0119poruszy\u0107", "d\u017celab\u0119", "westerski", "mithers", "szparnicowate", "aixeli", "kehjistanu", "wo\u0142oszyn", "nebout", "radwa\u0144ce", "bektaszyzm", "czuboustek", "oustalet", "ksi\u0119gofilm", "mozyrskie", "shelleyho", "happich", "pig\u0107", "middelkoop", "r\u00f3wnie\u017cbardzo", "aspiotis", "s\u0142upomeduzy", "latcherem", "magosiu", "szpadowy", "baria\u0144czycy", "fayuan", "spielmannsfluch", "jamowa\u0142", "onopko", "zseller", "discorde", "suchoruczenkow", "schind\u0142er", "poproch", "apdejtowa\u0107", "waniejszym", "britona", "lontra", "\u0434\u0443\u0445\u043e\u0432\u043d\u043e\u0439", "serebrennikov", "epinions", "wodewilista", "cular", "lanoye", "buchodonozor", "ilswunga", "fanthorpa", "nesasio", "basakis", "\u0441\u0442\u0435\u0432\u043e", "adesz\u0142a", "marsaglia", "pintusewicz", "\u043a\u0430\u043d\u0438\u043a\u0443\u043b\u044b", "morrellowi", "septynios", "skucy", "baho", "robodz", "owielkiej", "izaaka", "suvrinem", "oedogonium", "catolicismo", "ektorium", "lakewood", "battil", "obersiebenbrunn", "turczaka", "pusherman", "feigla", "zg\u0142usza\u0107", "tohu", "mockjack", "coscienza", "4398", "givenname", "sunajd", "capitolu", "hodzie", "zastavna", "amnu", "sparrmanii", "pirvan", "giarelli", "s\u0142owence", "maritzburgu", "niedostat", "r\u0131za", "jednoadresowy", "\u05d0\u05e0\u05d9", "wywolaly", "goddon\u00f3w", "homologowie", "celestiusz", "pleiskirchen", "powotano", "bhutan", "ylaton", "kletskij", "sezzxpolenxski", "kazin", "storjohanna", "trolujemy", "lutowisk", "faserverlaufes", "elec", "rz\u0119ciu", "dingsaller", "powlok\u0142amsi\u0119", "dreihundert", "drumnadrochit", "cherchant", "idsf", "holleina", "feluni\u0105", "pi\u0119ciodolarowe", "edoj", "nieobyczajny", "jeczne", "etsi", "eingestellte", "iniet", "hommeshurnet", "greuter", "kupey", "przy\u015blepe", "rosemiro", "lubienieckim", "kuczowic", "hypacrosaurus", "merxheim", "sp\u00e4therbst", "kajet\u0119", "zagajskiego", "atramentowoczarny", "prioziorsku", "rally", "neuropodobne", "g\u0119galska", "skarupa", "x\u00e9nia", "niad", "katechetka", "\u015bciowego", "ikramullah", "divyan", "emilczy\u0144skim", "suchitra", "yousaf", "trzez", "jasniejszy", "drobiazgowiec", "zechesz", "thungody", "your", "hughton", "olewska", "wersgorowie", "skpg", "valls", "midian", "rubaiyat", "bargeton", "kaznadziej\u00f3w", "stolicznyje", "apianus", "teleprocesory", "mpcv", "ababccbdd", "tomasy", "armeggaddon", "turon", "bothanina", "palmura", "epais", "rowi\u0105zanie", "sazonov", "deonema", "widmowc\u00f3w", "vernae", "tvmi", "arwid", "oblacyjny", "hawser", "wszechukrai\u0144skiego", "nsibandze", "\u015balakaya", "zuzank\u0119", "anselana", "\u014dmi", "cremona", "d\u017cawidem", "neutralit\u00e9", "rajamouli", "schulzowie", "elpidios", "dambhena", "koskoski", "barguzinskij", "diatrype", "baraty\u0144skiego", "aegirsson\u00f3w", "frawny", "canalett\u00f3w", "swinscow", "m\u00e9ho", "inklera", "bia\u0142ogwardzista", "serey", "roshanna", "j\u00f3z", "fr\u00f6schen", "sparco", "laeviusculus", "t\u014dkamachi", "motpese", "\u05e2\u05d5\u05d3",  ...

# %%
make_TSNE_plot(vecs_300_embedded, highlighted_words, random_words_300, 'TSNE plot for w2v_300')
# Out:
# <div>                            <div id="cc37e957-5616-4346-9c07-501bd5f0fc11" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cc37e957-5616-4346-9c07-501bd5f0fc11")) {                    Plotly.newPlot(                        "cc37e957-5616-4346-9c07-501bd5f0fc11",                        [{"mode": "markers", "name": "random", "text": ["verlucca", "bhalder", "myelmizacji", "mangowy", "ewellowie", "rohling", "romeyko", "socialphobia", "l'anello", "chapeaumange", "vaclavem", "nfe", "leptonektes", "wysznewe", "rozwioz\u0142o\u015b\u0107", "treason", "knowlesi", "lupulinus", "tej\u013ee", "pok\u0142onim", "nowobabilo\u0144czyk\u00f3w", "tilenau", "muzza", "mianta", "perittia", "si\u0119poruszy\u0107", "d\u017celab\u0119", "westerski", "mithers", "szparnicowate", "aixeli", "kehjistanu", "wo\u0142oszyn", "nebout", "radwa\u0144ce", "bektaszyzm", "czuboustek", "oustalet", "ksi\u0119gofilm", "mozyrskie", "shelleyho", "happich", "pig\u0107", "middelkoop", "r\u00f3wnie\u017cbardzo", "aspiotis", "s\u0142upomeduzy", "latcherem", "magosiu", "szpadowy", "baria\u0144czycy", "fayuan", "spielmannsfluch", "jamowa\u0142", "onopko", "zseller", "discorde", "suchoruczenkow", "schind\u0142er", "poproch", "apdejtowa\u0107", "waniejszym", "britona", "lontra", "\u0434\u0443\u0445\u043e\u0432\u043d\u043e\u0439", "serebrennikov", "epinions", "wodewilista", "cular", "lanoye", "buchodonozor", "ilswunga", "fanthorpa", "nesasio", "basakis", "\u0441\u0442\u0435\u0432\u043e", "adesz\u0142a", "marsaglia", "pintusewicz", "\u043a\u0430\u043d\u0438\u043a\u0443\u043b\u044b", "morrellowi", "septynios", "skucy", "baho", "robodz", "owielkiej", "izaaka", "suvrinem", "oedogonium", "catolicismo", "ektorium", "lakewood", "battil", "obersiebenbrunn", "turczaka", "pusherman", "feigla", "zg\u0142usza\u0107", "tohu", "mockjack", "coscienza", "4398", "givenname", "sunajd", "capitolu", "hodzie", "zastavna", "amnu", "sparrmanii", "pirvan", "giarelli", "s\u0142owence", "maritzburgu", "niedostat", "r\u0131za", "jednoadresowy", "\u05d0\u05e0\u05d9", "wywolaly", "goddon\u00f3w", "homologowie", "celestiusz", "pleiskirchen", "powotano", "bhutan", "ylaton", "kletskij", "sezzxpolenxski", "kazin", "storjohanna", "trolujemy", "lutowisk", "faserverlaufes", "elec", "rz\u0119ciu", "dingsaller", "powlok\u0142amsi\u0119", "dreihundert", "drumnadrochit", "cherchant", "idsf", "holleina", "feluni\u0105", "pi\u0119ciodolarowe", "edoj", "nieobyczajny", "jeczne", "etsi", "eingestellte", "iniet", "hommeshurnet", "greuter", "kupey", "przy\u015blepe", "rosemiro", "lubienieckim", "kuczowic", "hypacrosaurus", "merxheim", "sp\u00e4therbst", "kajet\u0119", "zagajskiego", "atramentowoczarny", "prioziorsku", "rally", "neuropodobne", "g\u0119galska", "skarupa", "x\u00e9nia", "niad", "katechetka", "\u015bciowego", "ikramullah", "divyan", "emilczy\u0144skim", "suchitra", "yousaf", "trzez", "jasniejszy", "drobiazgowiec", "zechesz", "thungody", "your", "hughton", "olewska", "wersgorowie", "skpg", "valls", "midian", "rubaiyat", "bargeton", "kaznadziej\u00f3w", "stolicznyje", "apianus", "teleprocesory", "mpcv", "ababccbdd", "tomasy", "armeggaddon", "turon", "bothanina", "palmura", "epais", "rowi\u0105zanie", "sazonov", "deonema", "widmowc\u00f3w", "vernae", "tvmi", "arwid", "oblacyjny", "hawser", "wszechukrai\u0144skiego", "nsibandze", "\u015balakaya", "zuzank\u0119", "anselana", "\u014dmi", "cremona", "d\u017cawidem", "neutralit\u00e9", "rajamouli", "schulzowie", "elpidios", "dambhena", "koskoski", "barguzinskij", "diatrype", "baraty\u0144skiego", "aegirsson\u00f3w", "frawny", "canalett\u00f3w", "swinscow", "m\u00e9ho", "inklera", "bia\u0142ogwardzista", "serey", "roshanna", "j\u00f3z", "fr\u00f6schen", "sparco", "laeviusculus", "t\u014dkamachi", "motpese", "\u05e2\u05d5\u05d3",  ...

# %% [markdown]
# Po zastosowaniu TSNE dla obu modeli mniejszy jest bardziej skupiony w jedną chmurą i nie ma żadncy outlierów, podczas gdy większy również w kształcie chmury posiada jednak mocno oddalone punkty takie jak np.: 'przegrupowanie', 'oblacyjny'. Oba modele uznały, że blisko 'lekarz' i 'lekarka' jest katechetka, natomiast większy model odnalazł jeszcze 'zuzankę', 'katechetkę' i 'faustynki'

# %% [markdown]
# ## Answer the following questions:
# * Compare results for all experiments with respect to the employed models (100 and 300-d)?
# Odpowiedzi udzieliłem pod zadaniami.
# * Compare results for single words and MWEs.
# Dla pojedynczych słów modele znalazły powiązane słowa, synonimy, które w większości miały sens. Dla bigramów natomiast zdarzały się 'dziwne' słowa.
# * How the results for MWEs could be improved?
# Słabe wyniki dla MWE wynikają z tego, że to narzędzie nie było wyuczone do pracy z tego typu danymi. Możnaby w procesie uczenie dodać do słownika najczęściej występujące w języku kolokację.
# * Are the results for albegraic operations biased?
# Tak proste operacje algebraiczne na wektorach o wielu wymiarach, o których nie wiemy czy reprezentują przestrzeń w sposób liniowy mogą mieć nieznany dla nas wpływ na powstały w ten sposób wektor, chociaż uzyskane wyniki sugerują iż takie proste uperacje dają w wybranych przypadkach oczekiwane efekty, ale potrafią też dla 'przedszkolanka + mężczyzna - kobieta' ocenić najbardziej podobne do słowa 'dryblas'.
# * According to t-SNE: do representations of similar word cluster together?
# Zdecydowanie tak, słowa o podobnym znaczeniu łączą się w grupy, chociażby podane przez nas słowa 'szkoda', 'krzywda' znajdują się bardzo blisko siebie.
